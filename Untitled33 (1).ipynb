# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
import sklearn
import nltk
import re
import textblob
import spacy
import wordcloud
import os

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#   text_type                                               text
# 0      spam  naturally irresistible your corporate identity...
# 1      spam  the stock trading gunslinger fanny is merrill ...
# 2      spam  unbelievable new homes made easy im wanting to...
# 3      spam  4 color printing special request additional in...
# 4      spam  do not have money get software cds from here s...

# %%
df.shape
# Out:
# (20348, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20348 entries, 0 to 20347
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text_type  20348 non-null  object
#  1   text       20348 non-null  object
# dtypes: object(2)
# memory usage: 318.1+ KB

# %%
data = pd.DataFrame(df['text_type'])

# %%
plt.figure(figsize=(8, 6))
df['text_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Text Types')
plt.xlabel('Text Type')
plt.ylabel('Count')
plt.xticks(rotation=0)

plt.show()

# %%
duplicate_texts = df.duplicated(subset=['text']).sum()

print(f"Number of duplicate text messages: {duplicate_texts}")
# Out:
# Number of duplicate text messages: 14

# %%
duplicate_rows = df[df.duplicated(subset=['text'], keep=False)]

# Display the duplicate rows
duplicate_rows


# unique_duplicate_texts = duplicate_rows['text'].unique()
# for i in unique_duplicate_texts:
#     print(i)
# Out:
#       text_type                                               text
# 20328       ham  SPAM DETECTION  User:     Username: @DillyBubb...
# 20329       ham  SPAM DETECTION  User:     Username: @DillyBubb...
# 20330       ham  SPAM DETECTION  User:     Username: @DillyBubb...
# 20331       ham  SPAM DETECTION  User:     Username: @DillyBubb...
# 20332       ham  SPAM DETECTION  User:     Username: @DillyBubb...
# 20333       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20334       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20335       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20336       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20337       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20338       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20339       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# 20340       ham  SPAM ALERT  🚔  User:     Username: @DillyBubbl...
# ...

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = " ".join(review for review in df.text)

# %%
wordcloud = WordCloud(width = 800, height = 400, background_color='white').generate(text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

# Sample data - replace with your actual data loading
data = {'text': ['This is a sample review.', 'Another review here.']}
df = pd.DataFrame(data)

text = " ".join(review for review in df.text)

# Rest of your wordcloud generation code

# %%
words = word_tokenize(text)

# %%
stop_words = set(stopwords.words('english'))
words_filtered = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

# %%
word_counts = Counter(words_filtered)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import make_pipeline

# %%
vectorizer = CountVectorizer()

# %%
print(df.columns)
# Out:
# Index(['text'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['text'], test_size=0.3, random_state=42)

# %%
model_MultinomialNB = make_pipeline(CountVectorizer(), MultinomialNB(alpha=3/10, fit_prior=True, class_prior=None))

# %%
model_MultinomialNB.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('multinomialnb', MultinomialNB(alpha=0.3))])

# %%
predictions = model_MultinomialNB.predict(X_test)

# %%
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.0000

# %%
recall = recall_score(y_test, predictions, pos_label='Another review here.')
print(f"Recall: {recall:.4f}")
# Out:
# Recall: 0.0000

# %%
accuracy = accuracy_score(y_test, predictions)

# %%
precision = precision_score(y_test, predictions, pos_label='Another review here.') # Use one of the valid labels as pos_label.
print(f"Precision: {precision:.4f}")
# Out:
# Precision: 0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
f1 = f1_score(y_test, predictions, pos_label='Another review here.') # Use one of the valid labels as pos_label.
print(f"F1-score: {f1:.4f}")
# Out:
# F1-score: 0.0000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import make_pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['text'], test_size=0.3, random_state=42)

# %%
model_SVC = make_pipeline(
    TfidfVectorizer(),
    SVC(C=1.0, kernel='linear', gamma='auto', probability=True, class_weight='balanced', max_iter=10000, verbose=False)  # SVM with linear kernel and C=1.0
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['text'], test_size=0.3, random_state=42)

# %%
print('Gradient Boosting with TF-IDF Vectorization')
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Gradient Boosting with TF-IDF Vectorization
# Accuracy: 0.0000
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
